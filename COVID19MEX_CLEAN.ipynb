# %%
import pandas as pd

# %%
covid19_df = pd.read_csv("Resources/Datos_Abiertos_COVID19MEXICO/200417COVID19MEXICO.csv")
#covid19_df = pd.read_csv("Resources/Datos_Abiertos_COVID19MEXICO/200424COVID19MEXICO.csv",encoding = "ISO-8859-1")
covid19_df.head()
# Out:
#   FECHA_ACTUALIZACION  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  ENTIDAD_NAC  \
# 0          2020-04-17       2       9          15     1           15
# 1          2020-04-17       2      12           9     1           15
# 2          2020-04-17       2       9          28     2           16
# 3          2020-04-17       2      12           9     2           99
# 4          2020-04-17       1       3          15     2           15
#
#    ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO ...   \
# 0           15             37              2    2020-04-09 ...
# 1            9              3              1    2020-04-16 ...
# 2           28             32              1    2020-04-06 ...
# 3            9             13              1    2020-04-17 ...
# 4           15            106              1    2020-04-16 ...
#
#   CARDIOVASCULAR OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  RESULTADO  \
# 0              2        2              2           2          2          1
# ...

# %%
covid19_df.dtypes
#covid19_df['FECHA_ACTUALIZACION'] =pd.to_datetime(covid19_df.FECHA_ACTUALIZACION)
# Out:
# FECHA_ACTUALIZACION    object
# ORIGEN                  int64
# SECTOR                  int64
# ENTIDAD_UM              int64
# SEXO                    int64
# ENTIDAD_NAC             int64
# ENTIDAD_RES             int64
# MUNICIPIO_RES           int64
# TIPO_PACIENTE           int64
# FECHA_INGRESO          object
# FECHA_SINTOMAS         object
# FECHA_DEF              object
# INTUBADO                int64
# NEUMONIA                int64
# EDAD                    int64
# NACIONALIDAD            int64
# EMBARAZO                int64
# HABLA_LENGUA_INDIG      int64
# DIABETES                int64
# EPOC                    int64
# ASMA                    int64
# INMUSUPR                int64
# HIPERTENSION            int64
# OTRA_COM                int64
# CARDIOVASCULAR          int64
# OBESIDAD                int64
# RENAL_CRONICA           int64
# TABAQUISMO              int64
# OTRO_CASO               int64
# RESULTADO               int64
# MIGRANTE                int64
# ...

# %%
xls = pd.ExcelFile('Resources/Datos_Abiertos_COVID19MEXICO/Catalogos_0412.xlsx')
sheets=xls.sheet_names
sheets
#df1 = pd.read_excel(xls, sheets[0])

#sorted(list(covid19_df["FECHA_INGRESO"].unique()))
#list(covid19_df["MIGRANTE"].unique())
#list(covid19_df.columns)
#covid19_df.info()
# Out:
# ['Catálogo ORIGEN',
#  'Catálogo SECTOR',
#  'Catálogo SEXO',
#  'Catálogo TIPO_PACIENTE',
#  'Catálogo SI_NO',
#  'Catálogo NACIONALIDAD',
#  'Catálogo RESULTADO',
#  'Catálogo de ENTIDADES',
#  'Catálogo MUNICIPIOS']

# %%
df1 = pd.read_excel(xls, sheets[1])
sector=df1.set_index('CLAVE').DESCRIPCIÓN.to_dict()
sector

df1 = pd.read_excel(xls, sheets[7])
entidad=df1.set_index('CLAVE_ENTIDAD').ENTIDAD_FEDERATIVA.to_dict()

df1 = pd.read_excel(xls, sheets[8])
municipio=df1.set_index('CLAVE_MUNICIPIO').MUNICIPIO.to_dict()

# %%
origen={1:"USMER",
        2:"Fuera de USMER",
        99:"No Especificado"}

tipo_paciente={1:"Ambulatorio",
               2:"Hospitalizado",
               99:"No Especificado"}
               
sexo={1:"Mujer",
      2:"Hombre",
      99:"No especificado"}

si_no={1:"Si",
       2:"No",
       97:"No Aplica",
       98:"Se Ignora",
       99:"No Especificado"}

nacionalidad={1:"Mexicana",
              2:"Extranjera",
              99:"No Especificado"}

resultado={1:"Positivo SARS-CoV-2",
           2:"No positivo SARS-CoV-2",
           3:"Resultado pendiente"}

pais={"97":"No Aplica",
      "99":"Se Ignora"}

# %%
covid19_df=covid19_df.replace({"ORIGEN":origen,
                               "PAIS_NACIONALIDAD":pais,
                               "TIPO_PACIENTE":tipo_paciente,
                               "INTUBADO":si_no,
                               "NEUMONIA":si_no,
                               "EMBARAZO":si_no,
                               "HABLA_LENGUA_INDIG":si_no,
                               "DIABETES":si_no,
                               "EPOC":si_no,
                               "ASMA":si_no,
                               "INMUSUPR":si_no,
                               "HIPERTENSION":si_no,
                               "OTRA_COM":si_no,
                               "CARDIOVASCULAR":si_no,
                               "OBESIDAD":si_no,
                               "RENAL_CRONICA":si_no,
                               "TABAQUISMO":si_no,
                               "MIGRANTE":si_no,
                               "PAIS_ORIGEN":pais,
                               "NACIONALIDAD":nacionalidad,
                               "UCI":si_no,
                               "RESULTADO":resultado,
                               "OTRO_CASO":si_no,
                               "SEXO":sexo,
                               "ENTIDAD_UM":entidad,
                               "SECTOR":sector,
                               "ENTIDAD_NAC":entidad,
                               "ENTIDAD_RES":entidad,
                               "MUNICIPIO_RES":municipio})

covid19_df.head()
# Out:
#   FECHA_ACTUALIZACION          ORIGEN   SECTOR        ENTIDAD_UM    SEXO  \
# 0          2020-04-17  Fuera de USMER  PRIVADA            MÉXICO   Mujer
# 1          2020-04-17  Fuera de USMER      SSA  CIUDAD DE MÉXICO   Mujer
# 2          2020-04-17  Fuera de USMER  PRIVADA        TAMAULIPAS  Hombre
# 3          2020-04-17  Fuera de USMER      SSA  CIUDAD DE MÉXICO  Hombre
# 4          2020-04-17           USMER  ESTATAL            MÉXICO  Hombre
#
#            ENTIDAD_NAC       ENTIDAD_RES            MUNICIPIO_RES  \
# 0               MÉXICO            MÉXICO                   PÁNUCO
# 1               MÉXICO  CIUDAD DE MÉXICO                 ATOLINGA
# 2  MICHOACÁN DE OCAMPO        TAMAULIPAS                  MORELOS
# 3      NO ESPECIFICADO  CIUDAD DE MÉXICO  GENERAL ENRIQUE ESTRADA
# 4               MÉXICO            MÉXICO                   YOBAÍN
#
#    TIPO_PACIENTE FECHA_INGRESO    ...     CARDIOVASCULAR OBESIDAD  \
# ...

# %%
covid19_df['FECHA_ACTUALIZACION'] =pd.to_datetime(covid19_df.FECHA_ACTUALIZACION)
covid19_df['FECHA_INGRESO'] =pd.to_datetime(covid19_df.FECHA_INGRESO)
covid19_df['FECHA_SINTOMAS'] =pd.to_datetime(covid19_df.FECHA_SINTOMAS)
covid19_df['FECHA_DEF'] =pd.to_datetime(covid19_df.FECHA_DEF)

covid19_df.to_csv("Output/NEW200417COVID19MEXICO.csv")

#covid19_df.dtypes
# Out:
# FECHA_ACTUALIZACION    datetime64[ns]
# ORIGEN                         object
# SECTOR                         object
# ENTIDAD_UM                     object
# SEXO                           object
# ENTIDAD_NAC                    object
# ENTIDAD_RES                    object
# MUNICIPIO_RES                  object
# TIPO_PACIENTE                  object
# FECHA_INGRESO          datetime64[ns]
# FECHA_SINTOMAS         datetime64[ns]
# FECHA_DEF              datetime64[ns]
# INTUBADO                       object
# NEUMONIA                       object
# EDAD                            int64
# NACIONALIDAD                   object
# EMBARAZO                       object
# HABLA_LENGUA_INDIG             object
# DIABETES                       object
# EPOC                           object
# ASMA                           object
# INMUSUPR                       object
# HIPERTENSION                   object
# OTRA_COM                       object
# CARDIOVASCULAR                 object
# ...

# %%
sorted_df=covid19_df.sort_values(by='FECHA_INGRESO',ascending=True)
pd.set_option('display.max_columns', None)
sorted_df
# Out:
#       FECHA_ACTUALIZACION          ORIGEN          SECTOR  \
# 8566           2020-04-17  Fuera de USMER            IMSS
# 11824          2020-04-17  Fuera de USMER            IMSS
# 1053           2020-04-17  Fuera de USMER            IMSS
# 46775          2020-04-17  Fuera de USMER            IMSS
# 2491           2020-04-17  Fuera de USMER            IMSS
# 48133          2020-04-17  Fuera de USMER            IMSS
# 19658          2020-04-17  Fuera de USMER            IMSS
# 35206          2020-04-17  Fuera de USMER            IMSS
# 20404          2020-04-17  Fuera de USMER            IMSS
# 48308          2020-04-17  Fuera de USMER            IMSS
# 38029          2020-04-17  Fuera de USMER            IMSS
# 22200          2020-04-17  Fuera de USMER            IMSS
# 10882          2020-04-17  Fuera de USMER            IMSS
# 3869           2020-04-17  Fuera de USMER            IMSS
# 4998           2020-04-17  Fuera de USMER  IMSS-BIENESTAR
# ...

# %%
sorted_df["RESULTADO"].value_counts()
# Out:
# No positivo SARS-CoV-2    28126
# Resultado pendiente       13364
# Positivo SARS-CoV-2        6875
# Name: RESULTADO, dtype: int64

# %%
sorted_df.loc[sorted_df["RESULTADO"]=="Positivo SARS-CoV-2"]
# Out:
#       FECHA_ACTUALIZACION          ORIGEN   SECTOR  \
# 13627          2020-04-17  Fuera de USMER      SSA
# 35419          2020-04-17  Fuera de USMER      SSA
# 18561          2020-04-17           USMER      SSA
# 34080          2020-04-17  Fuera de USMER      SSA
# 35510          2020-04-17  Fuera de USMER      SSA
# 48254          2020-04-17  Fuera de USMER      SSA
# 47092          2020-04-17           USMER     IMSS
# 34880          2020-04-17  Fuera de USMER  PRIVADA
# 5472           2020-04-17           USMER      SSA
# 38032          2020-04-17  Fuera de USMER  PRIVADA
# 48220          2020-04-17           USMER  PRIVADA
# 4795           2020-04-17  Fuera de USMER      SSA
# 20417          2020-04-17  Fuera de USMER   ISSSTE
# 4838           2020-04-17           USMER     IMSS
# 44259          2020-04-17           USMER      SSA
# 33678          2020-04-17           USMER      SSA
# 22735          2020-04-17           USMER      SSA
# ...

# %%
sorted_df.loc[sorted_df["RESULTADO"]=="Resultado pendiente"].count()
# Out:
# FECHA_ACTUALIZACION    13364
# ORIGEN                 13364
# SECTOR                 13364
# ENTIDAD_UM             13364
# SEXO                   13364
# ENTIDAD_NAC            13364
# ENTIDAD_RES            13364
# MUNICIPIO_RES          13364
# TIPO_PACIENTE          13364
# FECHA_INGRESO          13364
# FECHA_SINTOMAS         13364
# FECHA_DEF                153
# INTUBADO               13364
# NEUMONIA               13364
# EDAD                   13364
# NACIONALIDAD           13364
# EMBARAZO               13364
# HABLA_LENGUA_INDIG     13364
# DIABETES               13364
# EPOC                   13364
# ASMA                   13364
# INMUSUPR               13364
# HIPERTENSION           13364
# OTRA_COM               13364
# CARDIOVASCULAR         13364
# OBESIDAD               13364
# RENAL_CRONICA          13364
# TABAQUISMO             13364
# OTRO_CASO              13364
# RESULTADO              13364
# MIGRANTE               13364
# PAIS_NACIONALIDAD      13364
# ...

# %%
 sorted_df.loc[sorted_df["RESULTADO"]=="Resultado pendiente"]
# Out:
#       FECHA_ACTUALIZACION          ORIGEN   SECTOR  \
# 11824          2020-04-17  Fuera de USMER     IMSS
# 30357          2020-04-17  Fuera de USMER     IMSS
# 33002          2020-04-17  Fuera de USMER      SSA
# 11208          2020-04-17  Fuera de USMER     IMSS
# 9868           2020-04-17  Fuera de USMER     IMSS
# 29025          2020-04-17           USMER     IMSS
# 29722          2020-04-17  Fuera de USMER     IMSS
# 25421          2020-04-17  Fuera de USMER     IMSS
# 36533          2020-04-17  Fuera de USMER     IMSS
# 38673          2020-04-17  Fuera de USMER  PRIVADA
# 25409          2020-04-17           USMER     IMSS
# 27599          2020-04-17  Fuera de USMER     IMSS
# 25688          2020-04-17  Fuera de USMER     IMSS
# 5647           2020-04-17           USMER     IMSS
# 19899          2020-04-17           USMER      SSA
# 19767          2020-04-17  Fuera de USMER     IMSS
# 6349           2020-04-17  Fuera de USMER      SSA
# ...

# %%
pd.set_option('display.max_columns', None)
sorted_df.loc[((sorted_df["RESULTADO"]=="Resultado pendiente")|(sorted_df["RESULTADO"]=="Positivo SARS-CoV-2"))].head()
# Out:
#       FECHA_ACTUALIZACION          ORIGEN SECTOR            ENTIDAD_UM  \
# 11824          2020-04-17  Fuera de USMER   IMSS            NUEVO LEÓN
# 30357          2020-04-17  Fuera de USMER   IMSS  COAHUILA DE ZARAGOZA
# 33002          2020-04-17  Fuera de USMER    SSA               JALISCO
# 11208          2020-04-17  Fuera de USMER   IMSS             QUERÉTARO
# 9868           2020-04-17  Fuera de USMER   IMSS  COAHUILA DE ZARAGOZA
#
#          SEXO           ENTIDAD_NAC           ENTIDAD_RES  \
# 11824  Hombre            NUEVO LEÓN            NUEVO LEÓN
# 30357   Mujer  COAHUILA DE ZARAGOZA  COAHUILA DE ZARAGOZA
# 33002  Hombre               JALISCO               JALISCO
# 11208  Hombre            TAMAULIPAS             QUERÉTARO
# 9868   Hombre                PUEBLA      CIUDAD DE MÉXICO
#
#                       MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 11824                     TEPETONGO    Ambulatorio    2020-01-03
# ...

# %%
sorted_df.loc[sorted_df["ENTIDAD_RES"]=="CIUDAD DE MÉXICO"].head()
# Out:
#       FECHA_ACTUALIZACION          ORIGEN   SECTOR        ENTIDAD_UM    SEXO  \
# 2491           2020-04-17  Fuera de USMER     IMSS  CIUDAD DE MÉXICO  Hombre
# 3869           2020-04-17  Fuera de USMER     IMSS  CIUDAD DE MÉXICO   Mujer
# 8309           2020-04-17  Fuera de USMER  PRIVADA  CIUDAD DE MÉXICO   Mujer
# 33448          2020-04-17  Fuera de USMER     IMSS  CIUDAD DE MÉXICO  Hombre
# 21365          2020-04-17  Fuera de USMER  PRIVADA  CIUDAD DE MÉXICO   Mujer
#
#            ENTIDAD_NAC       ENTIDAD_RES               MUNICIPIO_RES  \
# 2491   NO ESPECIFICADO  CIUDAD DE MÉXICO                   FRESNILLO
# 3869   NO ESPECIFICADO  CIUDAD DE MÉXICO                      APULCO
# 8309   NO ESPECIFICADO  CIUDAD DE MÉXICO      GENERAL PÁNFILO NATERA
# 33448  NO ESPECIFICADO  CIUDAD DE MÉXICO  CAÑITAS DE FELIPE PESCADOR
# 21365  NO ESPECIFICADO  CIUDAD DE MÉXICO      GENERAL PÁNFILO NATERA
#
#        TIPO_PACIENTE FECHA_INGRESO FECHA_SINTOMAS FECHA_DEF   INTUBADO  \
# ...
